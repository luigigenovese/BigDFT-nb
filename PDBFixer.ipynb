# %% [markdown]
# <a href="https://colab.research.google.com/github/luigigenovese/BigDFT-nb/blob/master/PDBFixer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyfutile biopython condacolab
# !git clone --depth 1 -b devel https://gitlab.com/luigigenovese/bigdft-suite.git
# !cd bigdft-suite;git pull; cd -
# !pip install pybigdft
# Out:
# ...
# fatal: destination path 'bigdft-suite' already exists and is not an empty directory.
# Already up to date.
# /content
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 448.5/448.5 kB 7.5 MB/s eta 0:00:00
# ...

# %%
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.1.0-1/Mambaforge-23.1.0-1-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:17
# 🔁 Restarting kernel...

# %%
# !conda install pdbfixer
# Out:
# done
# failed with initial frozen solve. Retrying with flexible solve.
# done
# failed with initial frozen solve. Retrying with flexible solve.
#
# PackagesNotFoundError: The following packages are missing from the target environment:
#   - cudatoolkit=12.2

# %%
from BigDFT.Interop import OpenMMInterop as OI

# %%
sys=OI.fixed_system(pH=7.0,pdbid='7jx3',select_chains=[4,5,6])
# Out:
# /usr/local/lib/python3.10/site-packages/Bio/__init__.py:138: BiopythonWarning: You may be importing Biopython from inside the source tree. This is bad practice and might lead to downstream issues. In particular, you might encounter ImportErrors due to missing compiled C extensions. We recommend that you try running your code from outside the source tree. If you are outside the source tree then you have a setup.py file in an unexpected directory: /usr/local/lib/python3.10/site-packages
#   warnings.warn(
# /usr/local/lib/python3.10/site-packages/Bio/SeqIO/PdbIO.py:322: BiopythonParserWarning: 'HEADER' line not found; can't determine PDB ID.
#   warnings.warn(

# %%
_=sys.examine()
sys.unmatched_fragments
# Out:
# []

# %%
OI.optimize_system(sys,'S304-opt.pdb','amber14/protein.ff14SB.xml')

# %%
from BigDFT import BioQM
sys_opt=BioQM.BioSystem('S304-opt.pdb')
# Out:
# /usr/local/lib/python3.10/site-packages/Bio/SeqIO/PdbIO.py:322: BiopythonParserWarning: 'HEADER' line not found; can't determine PDB ID.
#   warnings.warn(

# %%
_=sys_opt.examine()
